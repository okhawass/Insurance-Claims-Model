# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/omar.elkhawass/Desktop/Insurance_Claim_Data.csv')

pd.set_option('display.max_columns', None) 
df.head(50)
# Out:
#    policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0    ID00001       0.515874        0.05             0.644231           C1
# 1    ID00002       0.672619        0.02             0.375000           C2
# 2    ID00003       0.841110        0.02             0.384615           C3
# 3    ID00004       0.900277        0.11             0.432692           C4
# 4    ID00005       0.596403        0.11             0.634615           C5
# 5    ID00006       1.018709        0.07             0.519231           C6
# 6    ID00007       0.097992        0.16             0.403846           C7
# 7    ID00008       0.509085        0.14             0.423077           C8
# 8    ID00009       0.282394        0.07             0.298077           C7
# 9    ID00010       0.566255        0.04             0.442308           C9
# 10   ID00011       0.951416        0.01             0.596154           C5
# 11   ID00012       0.083180        0.12             0.298077           C3
# 12   ID00013       0.045834        0.03             0.480769           C3
# 13   ID00014       0.520337        0.10             0.307692          C10
# 14   ID00015       0.213589        0.04             0.403846          C11
# 15   ID00016       0.897771        0.04             0.576923           C5
# 16   ID00017       0.321145        0.03             0.605769           C2
# 17   ID00018       0.241421        0.12             0.471154           C9
# 18   ID00019       0.295967        0.12             0.500000           C8
# 19   ID00020       0.758623        0.09             0.394231           C5
# 20   ID00021       0.301702        0.05             0.403846          C11
# 21   ID00022       0.527085        0.00             0.615385           C4
# 22   ID00023       0.630598        0.08             0.317308           C2
# 23   ID00024       0.999443        0.08             0.576923           C2
# 24   ID00025       0.020563        0.01             0.480769           C8
# 25   ID00026       0.240959        0.07             0.317308           C3
# 26   ID00027       0.775664        0.02             0.375000          C11
# 27   ID00028       0.524681        0.15             0.394231           C2
# 28   ID00029       0.543358        0.07             0.326923           C2
# 29   ID00030       1.124538        0.07             0.490385           C8
# 30   ID00031       1.102729        0.12             0.298077          C12
# 31   ID00032       1.146741        0.13             0.461538           C3
# 32   ID00033       0.796578        0.02             0.461538           C1
# 33   ID00034       0.530241        0.15             0.480769          C10
# 34   ID00035       0.468721        0.01             0.403846           C2
# 35   ID00036       1.193936        0.39             0.403846           C8
# 36   ID00037       0.758760        0.01             0.384615           C5
# 37   ID00038       1.152404        0.08             0.490385          C13
# 38   ID00039       1.124138        0.12             0.403846           C8
# 39   ID00040       0.128866        0.02             0.576923           C3
# 40   ID00041       0.247248        0.08             0.471154           C8
# 41   ID00042       0.112365        0.00             0.384615           C3
# 42   ID00043       0.844742        0.04             0.394231           C3
# 43   ID00044       0.132377        0.07             0.490385           C8
# 44   ID00045       1.055755        0.10             0.923077           C8
# 45   ID00046       0.715804        0.02             0.403846           C3
# 46   ID00047       1.216342        0.15             0.692308           C8
# 47   ID00048       0.082137        0.03             0.326923           C3
# 48   ID00049       1.235399        0.11             0.471154           C8
# 49   ID00050       0.345261        0.03             0.451923           C5
#
#     population_density  make  segment model fuel_type      max_torque  \
# 0                 4990     1        A    M1       CNG    60Nm@3500rpm
# 1                27003     1        A    M1       CNG    60Nm@3500rpm
# 2                 4076     1        A    M1       CNG    60Nm@3500rpm
# 3                21622     1       C1    M2    Petrol   113Nm@4400rpm
# 4                34738     2        A    M3    Petrol    91Nm@4250rpm
# 5                13051     3       C2    M4    Diesel   250Nm@2750rpm
# 6                 6112     4       B2    M5    Diesel   200Nm@3000rpm
# 7                 8794     1       B2    M6    Petrol   113Nm@4400rpm
# 8                 6112     3       C2    M4    Diesel   250Nm@2750rpm
# 9                17804     1       B2    M7    Petrol   113Nm@4400rpm
# 10               34738     1        A    M1       CNG    60Nm@3500rpm
# 11                4076     1       B1    M8       CNG  82.1Nm@3400rpm
# 12                4076     1       B2    M6    Petrol   113Nm@4400rpm
# 13               73430     1       B2    M6    Petrol   113Nm@4400rpm
# 14                6108     1        A    M1       CNG    60Nm@3500rpm
# 15               34738     3       C2    M4    Diesel   250Nm@2750rpm
# 16               27003     1        A    M1       CNG    60Nm@3500rpm
# 17               17804     5       C1    M9    Diesel   200Nm@1750rpm
# 18                8794     3       C2    M4    Diesel   250Nm@2750rpm
# 19               34738     1       B2    M6    Petrol   113Nm@4400rpm
# 20                6108     3       C2    M4    Diesel   250Nm@2750rpm
# 21               21622     1        A    M1       CNG    60Nm@3500rpm
# 22               27003     1  Utility   M10       CNG    85Nm@3000rpm
# 23               27003     3       C2    M4    Diesel   250Nm@2750rpm
# 24                8794     1        A    M1       CNG    60Nm@3500rpm
# 25                4076     1       B2    M6    Petrol   113Nm@4400rpm
# 26                6108     1        A    M1       CNG    60Nm@3500rpm
# 27               27003     1       B2    M7    Petrol   113Nm@4400rpm
# 28               27003     1       B2    M6    Petrol   113Nm@4400rpm
# 29                8794     1       B2    M6    Petrol   113Nm@4400rpm
# 30               34791     1       B1    M8       CNG  82.1Nm@3400rpm
# 31                4076     1       B2    M7    Petrol   113Nm@4400rpm
# 32                4990     1        A    M1       CNG    60Nm@3500rpm
# 33               73430     1       B2    M6    Petrol   113Nm@4400rpm
# 34               27003     1        A    M1       CNG    60Nm@3500rpm
# 35                8794     3       C2    M4    Diesel   250Nm@2750rpm
# 36               34738     1        A    M1       CNG    60Nm@3500rpm
# 37                5410     1       B1    M8       CNG  82.1Nm@3400rpm
# 38                8794     1       B2    M6    Petrol   113Nm@4400rpm
# 39                4076     1        A    M1       CNG    60Nm@3500rpm
# 40                8794     3       C2    M4    Diesel   250Nm@2750rpm
# 41                4076     1        A    M1       CNG    60Nm@3500rpm
# 42                4076     4       B2    M5    Diesel   200Nm@3000rpm
# 43                8794     1       B2    M6    Petrol   113Nm@4400rpm
# 44                8794     1       B2    M6    Petrol   113Nm@4400rpm
# 45                4076     1        A    M1       CNG    60Nm@3500rpm
# 46                8794     3       C2    M4    Diesel   250Nm@2750rpm
# 47                4076     3       C2    M4    Diesel   250Nm@2750rpm
# 48                8794     1       B2    M6    Petrol   113Nm@4400rpm
# 49               34738     1       B2    M6    Petrol   113Nm@4400rpm
#
#             max_power                engine_type  airbags is_esc  \
# 0    40.36bhp@6000rpm          F8D Petrol Engine        2     No
#
# 10                     No      No                Yes                No
# 11                     No      No                Yes                No
# 12                    Yes      No                Yes                No
# 13                    Yes      No                Yes                No
# 14                     No      No                Yes                No
# 15                    Yes     Yes                Yes               Yes
# 16                     No      No                Yes                No
# 17                    Yes      No                Yes               Yes
# 18                    Yes     Yes                Yes               Yes
# 19                    Yes      No                Yes                No
# 20                    Yes     Yes                Yes               Yes
# 21                     No      No                Yes                No
# 22                     No      No                Yes                No
# 23                    Yes     Yes                Yes               Yes
# 24                     No      No                Yes                No
# 25                    Yes      No                Yes                No
# 26                     No      No                Yes                No
# 27                    Yes      No                Yes               Yes
# 28                    Yes      No                Yes                No
# 29                    Yes      No                Yes                No
# 30                     No      No                Yes                No
# 31                    Yes      No                Yes               Yes
# 32                     No      No                Yes                No
# 33                    Yes      No                Yes                No
# 34                     No      No                Yes                No
# 35                    Yes     Yes                Yes               Yes
# 36                     No      No                Yes                No
# 37                     No      No                Yes                No
# 38                    Yes      No                Yes                No
# 39                     No      No                Yes                No
# 40                    Yes     Yes                Yes               Yes
# 41                     No      No                Yes                No
# 42                    Yes      No                Yes                No
# 43                    Yes      No                Yes                No
# 44                    Yes      No                Yes                No
# 45                     No      No                Yes                No
# 46                    Yes     Yes                Yes               Yes
# 47                    Yes     Yes                Yes               Yes
# 48                    Yes      No                Yes                No
# 49                    Yes      No                Yes                No
#
#    rear_brakes_type  displacement  cylinder transmission_type  gear_box  \
# 0              Drum           796         3            Manual         5
# 1              Drum           796         3            Manual         5
# 2              Drum           796         3            Manual         5
# 3              Drum          1197         4         Automatic         5
# 4              Drum           999         3         Automatic         5
# 5              Disc          1493         4         Automatic         6
# 6              Drum          1497         4            Manual         5
# 7              Drum          1197         4            Manual         5
# 8              Disc          1493         4         Automatic         6
# 9              Drum          1197         4         Automatic         5
# 10             Drum           796         3            Manual         5
# 11             Drum           998         3            Manual         5
# 12             Drum          1197         4            Manual         5
# 13             Drum          1197         4            Manual         5
# 14             Drum           796         3            Manual         5
# 15             Disc          1493         4         Automatic         6
# 16             Drum           796         3            Manual         5
# 17             Drum          1498         4            Manual         5
# 18             Disc          1493         4         Automatic         6
# 19             Drum          1197         4            Manual         5
# 20             Disc          1493         4         Automatic         6
# 21             Drum           796         3            Manual         5
# 22             Drum          1196         4            Manual         5
# 23             Disc          1493         4         Automatic         6
# 24             Drum           796         3            Manual         5
# 25             Drum          1197         4            Manual         5
# 26             Drum           796         3            Manual         5
# 27             Drum          1197         4         Automatic         5
# 28             Drum          1197         4            Manual         5
# 29             Drum          1197         4            Manual         5
# 30             Drum           998         3            Manual         5
# 31             Drum          1197         4         Automatic         5
# 32             Drum           796         3            Manual         5
# 33             Drum          1197         4            Manual         5
# 34             Drum           796         3            Manual         5
# 35             Disc          1493         4         Automatic         6
# 36             Drum           796         3            Manual         5
# 37             Drum           998         3            Manual         5
# 38             Drum          1197         4            Manual         5
# 39             Drum           796         3            Manual         5
# 3                  Yes                   No                    No
# 4                   No                   No                    No
# 5                  Yes                  Yes                   Yes
# 6                   No                   No                    No
# 7                  Yes                   No                    No
# 8                  Yes                  Yes                   Yes
# 9                  Yes                  Yes                   Yes
# 10                  No                   No                    No
# 11                  No                   No                    No
# 12                 Yes                   No                    No
# 13                 Yes                   No                    No
# 14                  No                   No                    No
# 15                 Yes                  Yes                   Yes
# 16                  No                   No                    No
# 17                 Yes                   No                    No
# 18                 Yes                  Yes                   Yes
# 19                 Yes                   No                    No
# 20                 Yes                  Yes                   Yes
# 21                  No                   No                    No
# 22                  No                   No                    No
# 23                 Yes                  Yes                   Yes
# 24                  No                   No                    No
# 25                 Yes                   No                    No
# 26                  No                   No                    No
# 27                 Yes                  Yes                   Yes
# 28                 Yes                   No                    No
# 29                 Yes                   No                    No
# 30                  No                   No                    No
# 31                 Yes                  Yes                   Yes
# 32                  No                   No                    No
# 33                 Yes                   No                    No
# 34                  No                   No                    No
# 35                 Yes                  Yes                   Yes
# 36                  No                   No                    No
# 37                  No                   No                    No
# 38                 Yes                   No                    No
# 39                  No                   No                    No
# 40                 Yes                  Yes                   Yes
# 41                  No                   No                    No
# 42                  No                   No                    No
# 43                 Yes                   No                    No
# 44                 Yes                   No                    No
# 45                  No                   No                    No
# 46                 Yes                  Yes                   Yes
# 47                 Yes                  Yes                   Yes
# 48                 Yes                   No                    No
# 49                 Yes                   No                    No
#
#    is_rear_window_defogger is_brake_assist is_power_door_locks  \
# 0                       No              No                  No
# 1                       No              No                  No
# 2                       No              No                  No
# 3                      Yes             Yes                 Yes
# 4                       No              No                 Yes
# 5                      Yes             Yes                 Yes
# 6                       No              No                 Yes
# 7                       No             Yes                 Yes
# 8                      Yes             Yes                 Yes
# 9                      Yes             Yes                 Yes
# 10                      No              No                  No
# 11                      No              No                 Yes
# 12                      No             Yes                 Yes
# 13                      No             Yes                 Yes
# 14                      No              No                  No
# 15                     Yes             Yes                 Yes
# 16                      No              No                  No
# 17                     Yes              No                 Yes
# 18                     Yes             Yes                 Yes
# 19                      No             Yes                 Yes
# 20                     Yes             Yes                 Yes
# 21                      No              No                  No
# 22                      No              No                  No
# 23                     Yes             Yes                 Yes
# 24                      No              No                  No
# 25                      No             Yes                 Yes
# 26                      No              No                  No
# 27                     Yes             Yes                 Yes
# 28                      No             Yes                 Yes
# 29                      No             Yes                 Yes
# 30                      No              No                 Yes
# 31                     Yes             Yes                 Yes
# 32                      No              No                  No
# 33                      No             Yes                 Yes
# 34                      No              No                  No
# 35                     Yes             Yes                 Yes
# 36                      No              No                  No
# 37                      No              No                 Yes
# 38                      No             Yes                 Yes
# 39                      No              No                  No
# 40                     Yes             Yes                 Yes
# 41                      No              No                  No
# 42                      No              No                 Yes
# 43                      No             Yes                 Yes
# 44                      No             Yes                 Yes
# 45                      No              No                  No
# 46                     Yes             Yes                 Yes
# 47                     Yes             Yes                 Yes
# 30                            No    Yes            Yes            2         0
# 31                           Yes    Yes            Yes            0         0
# 32                            No     No            Yes            0         0
# 33                           Yes    Yes            Yes            2         0
# 34                            No     No            Yes            0         0
# 35                            No    Yes            Yes            3         0
# 36                            No     No            Yes            0         0
# 37                            No    Yes            Yes            2         0
# 38                           Yes    Yes            Yes            2         0
# 39                            No     No            Yes            0         0
# 40                            No    Yes            Yes            3         0
# 41                            No     No            Yes            0         0
# 42                            No    Yes            Yes            5         0
# 43                           Yes    Yes            Yes            2         0
# 44                           Yes    Yes            Yes            2         0
# 45                            No     No            Yes            0         0
# 46                            No    Yes            Yes            3         0
# 47                            No    Yes            Yes            3         0
# 48                           Yes    Yes            Yes            2         0
# 49                           Yes    Yes            Yes            2         0

# %%
print(df[['max_torque','max_power']].dtypes)
df[['max_torque','max_power']].head()
# Out:
# max_torque    object
# max_power     object
# dtype: object
#       max_torque         max_power
# 0   60Nm@3500rpm  40.36bhp@6000rpm
# 1   60Nm@3500rpm  40.36bhp@6000rpm
# 2   60Nm@3500rpm  40.36bhp@6000rpm
# 3  113Nm@4400rpm  88.50bhp@6000rpm
# 4   91Nm@4250rpm  67.06bhp@5500rpm

# %%
# Pre-processing data: cleaning max_torque and max_power columns & converting to float

df['max_torque'] = df['max_torque'].str.extract(r'([-+]?[0-9]*\.?[0-9])').astype(float)
df['max_power'] = df['max_power'].str.extract(r'([-+]?[0-9]*\.?[0-9]+)').astype(float)

print(df['max_torque'].dtypes)
print(df['max_power'].dtypes)
df[['max_torque','max_power']].head(8)
# Out:
# float64
# float64
#    max_torque  max_power
# 0        60.0      40.36
# 1        60.0      40.36
# 2        60.0      40.36
# 3       113.0      88.50
# 4        91.0      67.06
# 5       250.0     113.45
# 6       200.0      88.77
# 7       113.0      88.50

# %%
# Now, let's check for any missing values in the dataset

df.isna().sum().sum()
# Out:
# 0

# %%
# Correlation Analysis on numeric X columns 
import seaborn as sns

correlation = df.select_dtypes("number").drop("is_claim", axis=1).corr()
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %%
# From this, we can see that most of our data's features are correlated.

# %%
# Analyzing cardinality in categorical X columns

df.select_dtypes("object").nunique()
# Out:
# policy_id                           58592
# area_cluster                           22
# segment                                 6
# model                                  11
# fuel_type                               3
# engine_type                            11
# is_esc                                  2
# is_adjustable_steering                  2
# is_tpms                                 2
# is_parking_sensors                      2
# is_parking_camera                       2
# rear_brakes_type                        2
# transmission_type                       2
# steering_type                           3
# is_front_fog_lights                     2
# is_rear_window_wiper                    2
# is_rear_window_washer                   2
# is_rear_window_defogger                 2
# is_brake_assist                         2
# is_power_door_locks                     2
# is_central_locking                      2
# is_power_steering                       2
# is_driver_seat_height_adjustable        2
# is_day_night_rear_view_mirror           2
# is_ecw                                  2
# is_speed_alert                          2
# dtype: int64

# %%
# policy_id and area_cluster are high in cardinality

# we will set policy_id as index as it is not relevant to the model
df = df.set_index('policy_id')

# we will drop the area_cluster column
df = df.drop('area_cluster', axis=1)

# %%
# Visualizing/Analyzing Target Column balance
import matplotlib.pyplot as plt

df['is_claim'].value_counts().plot(kind = 'bar')
plt.title('Target Column Balance')
plt.xlabel('Frequency')
plt.ylabel('Target Value')
# Out:
# Text(0, 0.5, 'Target Value')

# %%
# There is a huge imbalance in the target column, needs to be adressed before prediction models can be fitted 
# After splitting train and test portions, we will use an oversampler to fix the imbalance

# %%
# Splitting data for Train/Test 
from sklearn.model_selection import train_test_split

X = df.iloc[:, 0:len(df.columns)-1]   #excluding first column which is just an identifier 
Y = df.iloc[:, -1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# %%
X
# Out:
#            policy_tenure  age_of_car  age_of_policyholder  population_density  \
# policy_id
# ID00001         0.515874        0.05             0.644231                4990
# ID00002         0.672619        0.02             0.375000               27003
# ID00003         0.841110        0.02             0.384615                4076
# ID00004         0.900277        0.11             0.432692               21622
# ID00005         0.596403        0.11             0.634615               34738
# ...                  ...         ...                  ...                 ...
# ID58588         0.355089        0.13             0.644231                8794
# ID58589         1.199642        0.02             0.519231                7788
# ID58590         1.162273        0.05             0.451923               34738
# ID58591         1.236307        0.14             0.557692                8794
# ID58592         0.124429        0.02             0.442308                8794
#
#            make segment model fuel_type  max_torque  max_power  \
# policy_id
# ID00001       1       A    M1       CNG        60.0      40.36
# ID00002       1       A    M1       CNG        60.0      40.36
# ID00003       1       A    M1       CNG        60.0      40.36
# ID00004       1      C1    M2    Petrol       113.0      88.50
# ID00005       2       A    M3    Petrol        91.0      67.06
# ...         ...     ...   ...       ...         ...        ...
# ID58588       2       A    M3    Petrol        91.0      67.06
# ID58589       1       A    M1       CNG        60.0      40.36
# ID58590       1       A    M1       CNG        60.0      40.36
# ID58591       1      B2    M6    Petrol       113.0      88.50
# ID58592       3      C2    M4    Diesel       250.0     113.45
#
#                   engine_type  airbags is_esc is_adjustable_steering is_tpms  \
# policy_id
# ID00001     F8D Petrol Engine        2     No                     No      No
# ID00002     F8D Petrol Engine        2     No                     No      No
# ID00003     F8D Petrol Engine        2     No                     No      No
# ID00004    1.2 L K12N Dualjet        2    Yes                    Yes      No
# ID00005               1.0 SCe        2     No                     No      No
# ...                       ...      ...    ...                    ...     ...
# ID58588               1.0 SCe        2     No                     No      No
# ID58589     F8D Petrol Engine        2     No                     No      No
# ID58590     F8D Petrol Engine        2     No                     No      No
# ID58591     K Series Dual jet        2     No                    Yes      No
# ID58592         1.5 L U2 CRDi        6    Yes                    Yes     Yes
#
#           is_parking_sensors is_parking_camera rear_brakes_type  displacement  \
# policy_id
# ID00001                  Yes                No             Drum           796
# ID00002                  Yes                No             Drum           796
# ID00003                  Yes                No             Drum           796
# ID00004                  Yes               Yes             Drum          1197
# ID00005                   No               Yes             Drum           999
# ...                      ...               ...              ...           ...
# ID58588                   No               Yes             Drum           999
# ID58589                  Yes                No             Drum           796
# ID58590                  Yes                No             Drum           796
# ID58591                  Yes                No             Drum          1197
# ID58592                  Yes               Yes             Disc          1493
#
#            cylinder transmission_type  gear_box steering_type  turning_radius  \
# policy_id
# ID00001           3            Manual         5         Power             4.6
# ID00002           3            Manual         5         Power             4.6
# ID00003           3            Manual         5         Power             4.6
# ID00004           4         Automatic         5      Electric             4.8
# ID00005           3         Automatic         5      Electric             5.0
# ...             ...               ...       ...           ...             ...
# ID58588           3         Automatic         5      Electric             5.0
# ID58589           3            Manual         5         Power             4.6
# ID58590           3            Manual         5         Power             4.6
# ID58591           4            Manual         5      Electric             4.8
# ID58592           4         Automatic         6         Power             5.2
#
#            length  width  height  gross_weight is_front_fog_lights  \
# policy_id
# ID00001      3445   1515    1475          1185                  No
# ID00002      3445   1515    1475          1185                  No
# ID00003      3445   1515    1475          1185                  No
# ID00004      3995   1735    1515          1335                 Yes
# ID00005      3731   1579    1490          1155                  No
# ...           ...    ...     ...           ...                 ...
# ID58588      3731   1579    1490          1155                  No
# ID58589      3445   1515    1475          1185                  No
# ID58590      3445   1515    1475          1185                  No
# ID58591      3845   1735    1530          1335                 Yes
# ID58592      4300   1790    1635          1720                 Yes
#
#           is_rear_window_wiper is_rear_window_washer is_rear_window_defogger  \
# policy_id
# ID00001                     No                    No                      No
# ID00002                     No                    No                      No
# ID00003                     No                    No                      No
# ID00004                     No                    No                     Yes
# ID00005                     No                    No                      No
# ...                        ...                   ...                     ...
# ID58588                     No                    No                      No
# ID58589                     No                    No                      No
# ID58590                     No                    No                      No
# ID58591                     No                    No                      No
# ID58592                    Yes                   Yes                     Yes
#
#           is_brake_assist is_power_door_locks is_central_locking  \
# policy_id
# ID00001                No                  No                 No
# ID00002                No                  No                 No
# ID00003                No                  No                 No
# ID00004               Yes                 Yes                Yes
# ID00005                No                 Yes                Yes
# ...                   ...                 ...                ...
# ID58588                No                 Yes                Yes
# ID58589                No                  No                 No
# ID58590                No                  No                 No
# ID58591               Yes                 Yes                Yes
# ID58592               Yes                 Yes                Yes
#
#           is_power_steering is_driver_seat_height_adjustable  \
# policy_id
# ID00001                 Yes                               No
# ID00002                 Yes                               No
# ID00003                 Yes                               No
# ID00004                 Yes                              Yes
# ID00005                 Yes                               No
# ...                     ...                              ...
# ID58588                 Yes                               No
# ID58589                 Yes                               No
# ID58590                 Yes                               No
# ID58591                 Yes                              Yes
# ID58592                 Yes                              Yes
#
#           is_day_night_rear_view_mirror is_ecw is_speed_alert  ncap_rating
# policy_id
# ID00001                              No     No            Yes            0
# ID00002                              No     No            Yes            0
# ID00003                              No     No            Yes            0
# ID00004                             Yes    Yes            Yes            2
# ID00005                             Yes    Yes            Yes            2
# ...                                 ...    ...            ...          ...
# ID58588                             Yes    Yes            Yes            2
# ID58589                              No     No            Yes            0
# ID58590                              No     No            Yes            0
# ID58591                             Yes    Yes            Yes            2
# ID58592                              No    Yes            Yes            3
#
# [58592 rows x 41 columns]

# %%
Y
# Out:
# policy_id
# ID00001    0
# ID00002    0
# ID00003    0
# ID00004    0
# ID00005    0
#           ..
# ID58588    0
# ID58589    0
# ID58590    0
# ID58591    0
# ID58592    0
# Name: is_claim, Length: 58592, dtype: int64

# %%
X_train.shape, Y_train.shape
# Out:
# ((41014, 41), (41014,))

# %%
# to address the imbalance in target column
from imblearn.over_sampling import RandomOverSampler

over_sampler = RandomOverSampler(sampling_strategy = 'minority')
X_train_OS, Y_train_OS = over_sampler.fit_resample(X_train, Y_train)

# %%
# The dataset is now oversampled, adding more samples for the minority class Y col.

X_train_OS.shape, Y_train_OS.shape
# Out:
# ((76704, 41), (76704,))

# %%
# Comparing original target column balance VS new balance

df['is_claim'].value_counts().plot(kind = 'bar')
plt.title('Original Target Column Balance')
plt.xlabel('Frequency')
plt.ylabel('Target Value')
plt.show()

Y_train_OS.value_counts().plot(kind = 'bar')
plt.title('New Target Column Balance')
plt.xlabel('Frequency')
plt.ylabel('Target Value')
plt.show()

# %%
# Now that the target column is balanced, we will create a pipeline to preprocess the X columns further
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

numerical_X = X.columns[X.dtypes != 'object']
categorical_X = X.columns[X.dtypes == 'object']

step_1A = Pipeline(
    [
        ('1A', StandardScaler())
    ])

step_1B = Pipeline(
    [
        ('1B', OneHotEncoder())
    ])

step_1C = ColumnTransformer(
    [
        ('1C_i', step_1A, numerical_X),
        ('1C_ii', step_1B, categorical_X)
    ])

# %%
# Pipeline: Train and fit using AdaBoost
from sklearn.decomposition import PCA
from sklearn.ensemble import AdaBoostClassifier 

step2_AB = Pipeline(
    [
        ('1C', step_1C),
        ('PCA', PCA(n_components = 25)),
        ('AB', AdaBoostClassifier())
    ])

step2_AB.fit(X_train_OS, Y_train_OS)
# Out:
# Pipeline(steps=[('1C',
#                  ColumnTransformer(transformers=[('1C_i',
#                                                   Pipeline(steps=[('1A',
#                                                                    StandardScaler())]),
#                                                   Index(['policy_tenure', 'age_of_car', 'age_of_policyholder',
#        'population_density', 'make', 'max_torque', 'max_power', 'airbags',
#        'displacement', 'cylinder', 'gear_box', 'turning_radius', 'length',
#        'width', 'height', 'gross_weight', 'ncap_rating'],
#       dtype='object')...
#        'steering_type', 'is_front_fog_lights', 'is_rear_window_wiper',
#        'is_rear_window_washer', 'is_rear_window_defogger', 'is_brake_assist',
#        'is_power_door_locks', 'is_central_locking', 'is_power_steering',
#        'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror',
#        'is_ecw', 'is_speed_alert'],
#       dtype='object'))])),
#                 ('PCA', PCA(n_components=25)), ('AB', AdaBoostClassifier())])

# %%
#Pipeline: Train and fit using Gradient Boosting 
from sklearn.ensemble import GradientBoostingClassifier

step2_GB = Pipeline(
    [
        ('1C', step_1C),
        ('PCA', PCA(n_components = 25)),
        ('GB', GradientBoostingClassifier())
    ])

step2_GB.fit(X_train_OS, Y_train_OS)
# Out:
# Pipeline(steps=[('1C',
#                  ColumnTransformer(transformers=[('1C_i',
#                                                   Pipeline(steps=[('1A',
#                                                                    StandardScaler())]),
#                                                   Index(['policy_tenure', 'age_of_car', 'age_of_policyholder',
#        'population_density', 'make', 'max_torque', 'max_power', 'airbags',
#        'displacement', 'cylinder', 'gear_box', 'turning_radius', 'length',
#        'width', 'height', 'gross_weight', 'ncap_rating'],
#       dtype='object')...
#        'steering_type', 'is_front_fog_lights', 'is_rear_window_wiper',
#        'is_rear_window_washer', 'is_rear_window_defogger', 'is_brake_assist',
#        'is_power_door_locks', 'is_central_locking', 'is_power_steering',
#        'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror',
#        'is_ecw', 'is_speed_alert'],
#       dtype='object'))])),
#                 ('PCA', PCA(n_components=25)),
#                 ('GB', GradientBoostingClassifier())])

# %%
#Pipeline: Train and fit using Extreme Gradient Boosting 
import xgboost as xgb

step2_XGB = Pipeline(
    [
        ('1C', step_1C),
        ('PCA', PCA(n_components = 25)),
        ('XGB', xgb.XGBClassifier())
    ])

step2_XGB.fit(X_train_OS, Y_train_OS)
# Out:
# Pipeline(steps=[('1C',
#                  ColumnTransformer(transformers=[('1C_i',
#                                                   Pipeline(steps=[('1A',
#                                                                    StandardScaler())]),
#                                                   Index(['policy_tenure', 'age_of_car', 'age_of_policyholder',
#        'population_density', 'make', 'max_torque', 'max_power', 'airbags',
#        'displacement', 'cylinder', 'gear_box', 'turning_radius', 'length',
#        'width', 'height', 'gross_weight', 'ncap_rating'],
#       dtype='object')...
#                                feature_types=None, gamma=0, gpu_id=-1,
#                                grow_policy='depthwise', importance_type=None,
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_bin=256,
#                                max_cat_threshold=64, max_cat_to_onehot=4,
#                                max_delta_step=0, max_depth=6, max_leaves=0,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=0, num_parallel_tree=1, predictor='auto',
#                                random_state=0, ...))])

# %%
# Analyzing Accuracy
from sklearn.metrics import accuracy_score

print('AdaBoost Accuracy = ', round(step2_AB.score(X_test, Y_test) *100), '%')
print('Gradient Boosting Accuracy = ', round(step2_GB.score(X_test, Y_test) *100), '%')
print('Extreme Gradient Boosting Accuracy = ', round(step2_XGB.score(X_test, Y_test) *100), '%')
# Out:
# AdaBoost Accuracy =  58 %
# Gradient Boosting Accuracy =  59 %
# Extreme Gradient Boosting Accuracy =  89 %

# %%
# We will select the XGB Classifier as it predicts claims with the highest accuracy

# %%
#Visualizing Accuracy of model predictions 

pred = step2_XGB.predict(X_test)
comparisons = pd.DataFrame(Y_test)
comparisons['pred_is_claim'] = pred

comparisons['is_claim'].value_counts().plot(kind = 'bar')
plt.title('Actual Claims')
plt.show()
print('Actual number of claims = ', comparisons['is_claim'].sum())

comparisons['pred_is_claim'].value_counts().plot(kind = 'bar', color = 'g')
plt.title('Predicted Claims')
plt.show()
print('Predicted number of claims = ', comparisons['pred_is_claim'].sum(), '\n')
# Out:
# Actual number of claims =  1086
# Predicted number of claims =  905
